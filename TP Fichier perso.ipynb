# %% [markdown]
# # Avocado database
# ## Librairies

# %%
import numpy as np
import pandas as pd
import seaborn
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset

# %%
avocat= pd.read_csv("avocats.csv",sep=",")

# %%
avocat
# Out:
#        Unnamed: 0        Date  AveragePrice  TotVolume    V4046      V4225  \
# 0               0  2015-12-27          1.33   64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35   54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93  118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08   78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28   51039.60   941.48   43838.39
# ...           ...         ...           ...        ...      ...        ...
# 18244           7  2018-02-04          1.63   17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71   13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87   13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93   16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62   17489.58  2894.77    2356.13
#
#         V4770   TotBags  SmallBags  LargeBags  XLargeBags          type  year  \
# 0       48.16   8696.87    8603.62      93.25         0.0  conventional  2015
# 1       58.33   9505.56    9408.07      97.49         0.0  conventional  2015
# 2      130.50   8145.35    8042.21     103.14         0.0  conventional  2015
# 3       72.58   5811.16    5677.40     133.76         0.0  conventional  2015
# 4       75.78   6183.95    5986.26     197.69         0.0  conventional  2015
# ...       ...       ...        ...        ...         ...           ...   ...
# 18244    0.00  13498.67   13066.82     431.85         0.0       organic  2018
# 18245    0.00   9264.84    8940.04     324.80         0.0       organic  2018
# 18246  727.94   9394.11    9351.80      42.31         0.0       organic  2018
# 18247  727.01  10969.54   10919.54      50.00         0.0       organic  2018
# 18248  224.53  12014.15   11988.14      26.01         0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
del avocat['Unnamed: 0']

# %%
avocat
# Out:
#              Date  AveragePrice  TotVolume    V4046      V4225   V4770  \
# 0      2015-12-27          1.33   64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35   54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93  118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08   78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28   51039.60   941.48   43838.39   75.78
# ...           ...           ...        ...      ...        ...     ...
# 18244  2018-02-04          1.63   17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71   13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87   13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93   16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62   17489.58  2894.77    2356.13  224.53
#
#         TotBags  SmallBags  LargeBags  XLargeBags          type  year  \
# 0       8696.87    8603.62      93.25         0.0  conventional  2015
# 1       9505.56    9408.07      97.49         0.0  conventional  2015
# 2       8145.35    8042.21     103.14         0.0  conventional  2015
# 3       5811.16    5677.40     133.76         0.0  conventional  2015
# 4       6183.95    5986.26     197.69         0.0  conventional  2015
# ...         ...        ...        ...         ...           ...   ...
# 18244  13498.67   13066.82     431.85         0.0       organic  2018
# 18245   9264.84    8940.04     324.80         0.0       organic  2018
# 18246   9394.11    9351.80      42.31         0.0       organic  2018
# 18247  10969.54   10919.54      50.00         0.0       organic  2018
# 18248  12014.15   11988.14      26.01         0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %%
avocat.columns
# Out:
# Index(['Date', 'AveragePrice', 'TotVolume', 'V4046', 'V4225', 'V4770',
#        'TotBags', 'SmallBags', 'LargeBags', 'XLargeBags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
nb_lignes, nb_col = avocat.shape
print(f"nb lignes : {nb_lignes}\nnb col : {nb_col}")
# Out:
# nb lignes : 18249
# nb col : 13

# %%
avocat.dtypes
# Out:
# Date             object
# AveragePrice    float64
# TotVolume       float64
# V4046           float64
# V4225           float64
# V4770           float64
# TotBags         float64
# SmallBags       float64
# LargeBags       float64
# XLargeBags      float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# ## Analyse

# %%
# Total avocat par région
t1 = avocat.groupby("region").TotVolume.sum().sort_values()
t1.head()
# Out:
# region
# Syracuse      10942667.68
# Boise         14413187.75
# Spokane       15565275.48
# Albany        16067799.97
# Louisville    16097002.40
# Name: TotVolume, dtype: float64

# %%
# Total avocat US
avocat.TotVolume.sum()
# Out:
# 15523402593.400002

# %% [markdown]
# #### Moyenne de prix par région

# %%
# Prix moyen sur les dernières années d'un avocat par région US
avocat.groupby("region").AveragePrice.mean().sort_values().tail()
# Out:
# region
# Sacramento             1.621568
# Philadelphia           1.632130
# NewYork                1.727574
# SanFrancisco           1.804201
# HartfordSpringfield    1.818639
# Name: AveragePrice, dtype: float64

# %%
# Prix moyen sur les dernières années d'un avocat au US
avocat.AveragePrice.mean()
# Out:
# 1.4059784097758825

# %%
plt.rcParams['figure.figsize'] = [15, 6] # Taille du graphique en pouces
plt.rcParams['figure.dpi'] = 200 # résolution en points par pouce

# Blue > Orange > Green
avocat[(avocat.region=="HartfordSpringfield")].groupby("Date").AveragePrice.mean().plot(title="Prix Moyen dans 3 région")
avocat[(avocat.region=="StLouis")].groupby("Date").AveragePrice.mean().plot()
avocat[(avocat.region=="Houston")].groupby("Date").AveragePrice.mean().plot()

# %%
avocat[(avocat.region=="HartfordSpringfield")].groupby("Date").TotVolume.mean().plot(title= "Nombre de vente d'avocat dans 3 région")
avocat[(avocat.region=="StLouis")].groupby("Date").TotVolume.mean().plot()
avocat[(avocat.region=="Houston")].groupby("Date").TotVolume.mean().plot()

# %% [markdown]
# #### Type d'avocat par région

# %%
# Variété HASS > 3 PLU correspondant aux tailles
avocat[(avocat.region=="HartfordSpringfield")].groupby("Date").V4046.sum().plot(title = "Comparaison des PLU d'avocat vendu")
avocat[(avocat.region=="HartfordSpringfield")].groupby("Date").V4225.sum().plot()
avocat[(avocat.region=="HartfordSpringfield")].groupby("Date").V4770.sum().plot()

# %%
avocat[(avocat.region=="StLouis")].groupby("Date").V4046.sum().plot()
avocat[(avocat.region=="StLouis")].groupby("Date").V4225.sum().plot()
avocat[(avocat.region=="StLouis")].groupby("Date").V4770.sum().plot()

# %%
avocat[(avocat.region=="Houston")].groupby("Date").V4046.sum().plot()
avocat[(avocat.region=="Houston")].groupby("Date").V4225.sum().plot()
avocat[(avocat.region=="Houston")].groupby("Date").V4770.sum().plot()

# %% [markdown]
# #### Types d'avocats

# %%
Type =avocat.pivot_table('TotVolume',index='Date',columns='type',aggfunc=sum)
Type.tail() #Tail = queue du tableau
# Out:
# type        conventional     organic
# Date
# 2018-02-25  1.053272e+08  3904273.18
# 2018-03-04  1.074543e+08  4390650.71
# 2018-03-11  1.070323e+08  4432869.50
# 2018-03-18  1.091914e+08  4482550.51
# 2018-03-25  1.140834e+08  4185583.32

# %%
Type.plot(title="Type d'avocats")

# %%
avocat[(avocat.region=="StLouis")].groupby("Date").V4046.sum().plot()
